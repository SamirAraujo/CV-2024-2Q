# %%
# L1_1

import numpy as np
import cv2 as cv

img = cv.imread('messi5.jpg',0)
cv.imshow('image',img)
k = cv.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv.imwrite('original/messigray.png',img)
    cv.destroyAllWindows()

# %%
# #L1_2

import time
import numpy as np
import cv2 as cv

cap = cv.VideoCapture('big_buck_bunny.mp4')

while(cap.isOpened()):
    ret, frame = cap.read()
    
    if ret==True:
        # show the frame
        cv.imshow('frame',frame)

        #wait next frame by 40ms - 25fps
        time.sleep(1/10.0) 
        
        if cv.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
               
cap.release()
cv.destroyAllWindows()

# %%
# #L1_3

import numpy as np
import cv2 as cv

cap = cv.VideoCapture(0)

if not cap.isOpened():
    print("Cannot open camera")
    exit()
    
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    
    # Display the resulting frame
    cv.imshow('frame', frame)

    k = cv.waitKey(1)

    if k == ord('q'):
        break

    if k == ord('x'):
        cv.imwrite('foto1.png', frame)
        print("Foto tirada com sucesso!")


# When everything done, release the capture
cap.release()
cv.destroyAllWindows()

# %%
#L1_4

import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)

# Get current width of frame
width = cap.get(cv.CAP_PROP_FRAME_WIDTH)   # float
# Get current height of frame
height = cap.get(cv.CAP_PROP_FRAME_HEIGHT) # float

fps = 60.0

# Define the codec and create VideoWriter object
fourcc = cv.VideoWriter_fourcc(*'XVID')
out = cv.VideoWriter('saida.avi', fourcc, fps, (int(width),int(height)) )

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # frame = cv.flip(frame, 0)
    # write the flipped frame
    out.write(frame)
    cv.imshow('frame', frame)
    k = cv.waitKey(1) 
    if k == ord('q'):
        break

cap.release()
out.release()
cv.destroyAllWindows()

# %% [markdown]
# # QUESTÕES
#
# ## Por que a janela aberta não mostra a imagem colorida? L1_1
#
# R: A janela não mostra a imagem colorida, pois ...
#
# ---
#
# ## Modifique o programa para que as imagens sejam exibidas mais rápidamente e depois para que sejam exibidas mais lentamente. Responda: qual a explicação de alteração de velocidade de exibição, e apresente suas soluções detalhadamente. L1_2
#
# Para alterar a velocidade de exibição, podemos alterar a taxa de frames por segundo(FPS) que são reproduzidos. Assim,para conseguirmos executar o video mais rapidamente,isto é, com maior taxa de frames por segundo, podemos alterar o trecho de codigo responsável por isso. A solução a seguir apresenta a taxa de um frame a cada 40ms,isto é, 25 FPS.
#
# time.sleep(1/25.0)
#
# O comando a seguir reproduzirá o video com taxa de 1 frame a cada 1ms, isto é, 1000 FPS. Assim, o video é reproduzido mais rapidamente
#
# time.sleep(1/1000.0)
#
# Porém o comando a seguir reproduzir o video com taxa de 1 frame a cada 100ms, isto é, 10 FPS. Assim, o vídeo é reproduzido mais lentamente
#
# time.sleep(1/10.0)
#
# ---
#
# ## Modifique o programa para que uma imagem da câmera seja salva num arquivo “foto1.png” no momento em que for clicada a tecla ‘x’ no teclado. Apresente o resultado e sua solução detalhadamente. L1_3
#
# Os comandos a seguir executam a operação de terminar a gravação do vídeo ao apertar a tecla `q` ou salvar em formato .ppg a foto do frame no momento em que a tecla `x`. O restante do programa original foi mantido.
#
#
# ``` python
# k = cv.waitKey(1)
#
# if k == ord('q'):
#     break
#
# if k == ord('x'):
#     cv.imwrite('foto1.png', frame)
#     print("Foto tirada com sucesso!")
# ```
# ---
#
# ## Modifique o programa para que as imagens gravadas estejam “normais” no arquivo de video salvo, e apresentem uma velocidade de exibição adequada. Apresente o resultado e sua solução detalhadamente. L1_4
#
# Para atingir o objetivo proposto foi modificados apenas algumas linhas do código. Primeiramente a linha onde o FPS é informado foi alterada, para a variável `fps`conter 60. E, também foi comentada a linha que fazia com que o video gerado fosse gerado de maneira "flipada". A seguir está como foram definidas as novas linhas de código.
# ```python
# fps = 60
#     #frame = cv.flip(frame, 0)
# ```
# ---
#
# ## Se for necessário alterar a imagem, ou seja realizando alguma operação de procesamento nela, em que ponto dos quatro programas estudados isso deve ser realizado?
#
# Para realizar modificações na imagem, o ponto correto do código a inserir elas é no trecho a seguir. O trecho a seguir é o loop While, que é executado enquando o video estiver sendo gravado sem erros.
# ```python
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         print("Can't receive frame (stream end?). Exiting ...")
#         break
#     # frame = cv.flip(frame, 0)
#     # write the flipped frame
#     out.write(frame)
#     cv.imshow('frame', frame)
#     k = cv.waitKey(1)
#     if k == ord('q'):
#         break
# ```
